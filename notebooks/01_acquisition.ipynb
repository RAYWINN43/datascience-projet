# %%
# Installation automatique des dépendances requises dans le noyau Jupyter actuel
# %pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: pandas>=2.0.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from -r ../requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: numpy>=1.24.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from -r ../requirements.txt (line 3)) (2.3.5)
# Requirement already satisfied: scikit-learn>=1.2.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from -r ../requirements.txt (line 6)) (1.7.2)
# Requirement already satisfied: tensorflow>=2.12.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from -r ../requirements.txt (line 7)) (2.21.0)
# Requirement already satisfied: matplotlib>=3.7.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from -r ../requirements.txt (line 10)) (3.10.6)
# Requirement already satisfied: seaborn>=0.12.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from -r ../requirements.txt (line 11)) (0.13.2)
# Requirement already satisfied: plotnine>=0.12.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from -r ../requirements.txt (line 12)) (0.15.4)
# Requirement already satisfied: ipykernel in c:\users\utilisateur\anaconda3\lib\site-packages (from -r ../requirements.txt (line 15)) (6.31.0)
# Requirement already satisfied: jupyter in c:\users\utilisateur\anaconda3\lib\site-packages (from -r ../requirements.txt (line 16)) (1.1.1)
# Requirement already satisfied: quarto in c:\users\utilisateur\anaconda3\lib\site-packages (from -r ../requirements.txt (line 17)) (0.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\utilisateur\anaconda3\lib\site-packages (from pandas>=2.0.0->-r ../requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from pandas>=2.0.0->-r ../requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\utilisateur\anaconda3\lib\site-packages (from pandas>=2.0.0->-r ../requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from scikit-learn>=1.2.0->-r ../requirements.txt (line 6)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from scikit-learn>=1.2.0->-r ../requirements.txt (line 6)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from scikit-learn>=1.2.0->-r ../requirements.txt (line 6)) (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\utilisateur\anaconda3\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\utilisateur\anaconda3\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.4.0)
# Requirement already satisfied: packaging in c:\users\utilisateur\anaconda3\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (25.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\utilisateur\anaconda3\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\utilisateur\anaconda3\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\utilisateur\anaconda3\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.14.1)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\utilisateur\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\utilisateur\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\utilisateur\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (2025.11.12)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\utilisateur\anaconda3\lib\site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\utilisateur\anaconda3\lib\site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (3.2.5)
# Requirement already satisfied: mizani~=0.14.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from plotnine>=0.12.0->-r ../requirements.txt (line 12)) (0.14.4)
# Requirement already satisfied: statsmodels>=0.14.6 in c:\users\utilisateur\anaconda3\lib\site-packages (from plotnine>=0.12.0->-r ../requirements.txt (line 12)) (0.14.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from ipykernel->-r ../requirements.txt (line 15)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\utilisateur\anaconda3\lib\site-packages (from ipykernel->-r ../requirements.txt (line 15)) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from ipykernel->-r ../requirements.txt (line 15)) (9.7.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from ipykernel->-r ../requirements.txt (line 15)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\utilisateur\anaconda3\lib\site-packages (from ipykernel->-r ../requirements.txt (line 15)) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from ipykernel->-r ../requirements.txt (line 15)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\utilisateur\anaconda3\lib\site-packages (from ipykernel->-r ../requirements.txt (line 15)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\utilisateur\anaconda3\lib\site-packages (from ipykernel->-r ../requirements.txt (line 15)) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\utilisateur\anaconda3\lib\site-packages (from ipykernel->-r ../requirements.txt (line 15)) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\utilisateur\anaconda3\lib\site-packages (from ipykernel->-r ../requirements.txt (line 15)) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from ipykernel->-r ../requirements.txt (line 15)) (5.14.3)
# Requirement already satisfied: notebook in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyter->-r ../requirements.txt (line 16)) (7.4.5)
# Requirement already satisfied: jupyter-console in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyter->-r ../requirements.txt (line 16)) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyter->-r ../requirements.txt (line 16)) (7.16.6)
# Requirement already satisfied: ipywidgets in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyter->-r ../requirements.txt (line 16)) (8.1.7)
# Requirement already satisfied: jupyterlab in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyter->-r ../requirements.txt (line 16)) (4.4.7)
# Requirement already satisfied: nbformat in c:\users\utilisateur\anaconda3\lib\site-packages (from quarto->-r ../requirements.txt (line 17)) (5.10.4)
# Requirement already satisfied: nbclient in c:\users\utilisateur\anaconda3\lib\site-packages (from quarto->-r ../requirements.txt (line 17)) (0.10.2)
# Requirement already satisfied: pyyaml in c:\users\utilisateur\anaconda3\lib\site-packages (from quarto->-r ../requirements.txt (line 17)) (6.0.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.45.1)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\utilisateur\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\utilisateur\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\utilisateur\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\utilisateur\anaconda3\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\utilisateur\anaconda3\lib\site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (0.8.5)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r ../requirements.txt (line 15)) (4.5.0)
# Requirement already satisfied: pywin32>=300 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r ../requirements.txt (line 15)) (311)
# Requirement already satisfied: rich in c:\users\utilisateur\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (14.2.0)
# Requirement already satisfied: namex in c:\users\utilisateur\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.1.0)
# Requirement already satisfied: optree in c:\users\utilisateur\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.19.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\utilisateur\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (0.2.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\utilisateur\anaconda3\lib\site-packages (from statsmodels>=0.14.6->plotnine>=0.12.0->-r ../requirements.txt (line 12)) (1.0.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\utilisateur\anaconda3\lib\site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 16)) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\utilisateur\anaconda3\lib\site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 16)) (3.0.15)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 16)) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.2.4)
# Requirement already satisfied: anyio in c:\users\utilisateur\anaconda3\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\utilisateur\anaconda3\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\utilisateur\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (4.25.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\utilisateur\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from jinja2>=3.0.3->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\utilisateur\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\utilisateur\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.28.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (3.2.1)
# Requirement already satisfied: rfc3339-validator in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\utilisateur\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\utilisateur\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\utilisateur\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\utilisateur\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\utilisateur\anaconda3\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 16)) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 16)) (6.3.0)
# Requirement already satisfied: defusedxml in c:\users\utilisateur\anaconda3\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 16)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\utilisateur\anaconda3\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 16)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\utilisateur\anaconda3\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 16)) (3.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 16)) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\utilisateur\anaconda3\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 16)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 16)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\utilisateur\anaconda3\lib\site-packages (from nbformat->quarto->-r ../requirements.txt (line 17)) (2.21.2)
# Requirement already satisfied: lark>=1.2.2 in c:\users\utilisateur\anaconda3\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\utilisateur\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.23)
# Requirement already satisfied: soupsieve>1.2 in c:\users\utilisateur\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->-r ../requirements.txt (line 16)) (2.5)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 📥 Étape 1 : Acquisition des Données & Multi-Sources (Squelette Étudiant)
#
# Cette étape correspond au premier chapitre du pipeline de Data Science. L'objectif est d'identifier, d'importer et de consolider vos jeux de données bruts issus de différentes sources (fichiers CSV locaux, requêtes API, bases de données, etc.).

# %% [markdown]
# ### 1. Initialisation de l'environnement

# %%
import os
import sys
import pandas as pd
import numpy as np
 
# Ajout du dossier parent au chemin de recherche des modules
sys.path.append(os.path.abspath('..'))

print("Libraries importées avec succès ! Prêt pour l'étape d'Acquisition des Données.")
# Out:
# Libraries importées avec succès ! Prêt pour l'étape d'Acquisition des Données.

# %% [markdown]
# ### 2. Chargement de la source de données principale
#
# Chargement de notre jeu de données grace a un fichier CSV stocké dans data/raw/

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Load a DataFrame with a specific version of a CSV
df = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    "unsdsn/world-happiness/versions/1",
    "2016.csv",
)
# Out:
# Dimensions du dataset principal : (150000, 21)
#          Date      Time    Booking ID   Booking Status   Customer ID  \
# 0  2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1  2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2  2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3  2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4  2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
#
#     Vehicle Type      Pickup Location      Drop Location  Avg VTAT  Avg CTAT  \
# 0          eBike          Palam Vihar            Jhilmil       NaN       NaN
# 1       Go Sedan        Shastri Nagar  Gurgaon Sector 56       4.9      14.0
# 2           Auto              Khandsa      Malviya Nagar      13.4      25.8
# 3  Premier Sedan  Central Secretariat           Inderlok      13.1      28.5
# 4           Bike     Ghitorni Village        Khan Market       5.3      19.6
#
#    ...  Reason for cancelling by Customer Cancelled Rides by Driver  \
# 0  ...                                NaN                       NaN
# 1  ...                                NaN                       NaN
# 2  ...                                NaN                       NaN
# 3  ...                                NaN                       NaN
# 4  ...                                NaN                       NaN
#
#    Driver Cancellation Reason Incomplete Rides  Incomplete Rides Reason  \
# 0                         NaN              NaN                      NaN
# 1                         NaN              1.0        Vehicle Breakdown
# 2                         NaN              NaN                      NaN
# 3                         NaN              NaN                      NaN
# 4                         NaN              NaN                      NaN
#
#   Booking Value  Ride Distance  Driver Ratings  Customer Rating  \
# 0           NaN            NaN             NaN              NaN
# 1         237.0           5.73             NaN              NaN
# 2         627.0          13.58             4.9              4.9
# 3         416.0          34.02             4.6              5.0
# 4         737.0          48.21             4.1              4.3
#
#    Payment Method
# 0             NaN
# 1             UPI
# 2      Debit Card
# 3             UPI
# 4             UPI
#
# [5 rows x 21 columns]

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Load a DataFrame with a specific version of a CSV
df = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    "unsdsn/world-happiness/versions/1",
    "2016.csv",
)

# %%
# Spécifiez le chemin vers votre jeu de données principal
main_data_path = '../data/raw/ncr_ride_bookings.csv'

# TODO: Charger le dataset à l'aide de Pandas
df_main = pd.read_csv(main_data_path)

# Affichez la taille et les premières lignes
print(f"Dimensions du dataset principal : {df_main.shape}")
df_main.head()

# %% [markdown]
# ### 3. Intégration de données secondaires (Multi-Sources)
#
# **À COMPLÉTER PAR L'ÉTUDIANT :**
# Mettez en place la récupération de vos données complémentaires (par exemple, appels d'API fictifs ou réels, données météo, géographiques, ou financiers complémentaires).

# %%
# TODO: Récupérer/générer ou charger vos données secondaires
# Exemple fictif : création d'un DataFrame complémentaire avec des catégories/labels
categories_info = pd.DataFrame({
    'category': ['A', 'B', 'C'],
    'description': ['Premium', 'Standard', 'Basique'],
    'coef_multiplicateur': [1.5, 1.0, 0.8]
})

print("Données secondaires prêtes :")
categories_info.head()

# %% [markdown]
# ### 4. Fusion des sources (Optionnel)
#
# **À COMPLÉTER PAR L'ÉTUDIANT :**
# Associez vos différentes sources de données en utilisant des jointures (`pd.merge`) pertinentes.

# %%
# TODO: Effectuer la jointure de vos tables si nécessaire
df_merged = pd.merge(df_main, categories_info, on='category', how='left')
df_merged.head()

# %% [markdown]
# ### 5. Consignation des données d'entrée brutes
#
# Sauvegardez l'état brut de vos données d'entrée pour la suite du pipeline.

# %%
# Sauvegarde du fichier brute fusionné si applicable
print("Acquisition terminée avec succès !")
